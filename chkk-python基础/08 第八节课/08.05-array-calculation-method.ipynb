# %% [markdown]
# # 5 numpy.array方法

# %%
# %pylab
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## 5.1 求和

# %%
a = array([[1,2,3], 
           [4,5,6]])

# %% [markdown]
# 求所有元素的和：

# %%
sum(a)
# Out:
# 21

# %% [markdown]
# 指定求和的维度：

# %% [markdown]
# 沿着第一维求和：（行）--可以理解为对每一列求和

# %%
sum(a, axis=0)
# Out:
# array([5, 7, 9])

# %% [markdown]
# 沿着第二维求和：

# %%
sum(a, axis=1)
# Out:
# array([ 6, 15])

# %% [markdown]
# 沿着最后一维求和：

# %%
sum(a, axis=-1)
# Out:
# array([ 6, 15])

# %% [markdown]
# 或者使用 `sum` 方法：

# %%
a.sum()
# Out:
# 21

# %%
a.sum(axis=0)
# Out:
# array([5, 7, 9])

# %%
a.sum(axis=-1)
# Out:
# array([ 6, 15])

# %% [markdown]
# ## 5.2 求积

# %% [markdown]
# 求所有元素的乘积：

# %%
a.prod()
# Out:
# 720

# %% [markdown]
# 或者使用函数形式：

# %%
prod(a, axis=0)
# Out:
# array([ 4, 10, 18])

# %% [markdown]
# ## 5.3 求最大最小值

# %%
from numpy.random import rand
a = rand(3, 4)
# %precision 3
a
# Out:
# array([[  3.880e-01,   8.259e-01,   2.689e-01,   3.782e-04],
#        [  8.157e-01,   4.586e-01,   5.074e-02,   4.952e-01],
#        [  9.703e-01,   5.821e-01,   1.313e-01,   9.595e-02]])

# %% [markdown]
# 全局最小：

# %%
a.min()
# Out:
# 0.000

# %% [markdown]
# 沿着某个轴的最小：

# %%
a.min(axis=0)
# Out:
# array([  3.880e-01,   4.586e-01,   5.074e-02,   3.782e-04])

# %% [markdown]
# 全局最大：

# %%
a.max()
# Out:
# 0.913

# %% [markdown]
# 沿着某个轴的最大：

# %%
a.max(axis=-1)
# Out:
# array([ 0.844,  0.469,  0.913])

# %% [markdown]
# ## 5.4 最大最小值的位置

# %% [markdown]
# 使用 `argmin, argmax` 方法：

# %%
a.argmin()
# Out:
# 6

# %%
a.argmin(axis=0)
# Out:
# array([1, 1, 1, 1], dtype=int64)

# %% [markdown]
# ## 5.5 均值

# %% [markdown]
# 可以使用 `mean` 方法：

# %%
a = array([[1,2,3],[4,5,6]])

# %%
a.mean()
# Out:
# 3.500

# %%
a.mean(axis=-1)
# Out:
# array([ 2.,  5.])

# %% [markdown]
# 也可以使用 `mean` 函数：

# %%
mean(a)
# Out:
# 3.500

# %% [markdown]
# 还可以使用 `average` 函数：

# %%
average(a, axis = 0)
# Out:
# array([ 2.5,  3.5,  4.5])

# %% [markdown]
# `average` 函数还支持加权平均：

# %%
average(a, axis = 0, weights=[1,2])
# Out:
# array([ 3.,  4.,  5.])

# %% [markdown]
# ## 5.6 标准差

# %% [markdown]
# 用 `std` 方法计算标准差：

# %%
a.std(axis=1)
# Out:
# array([ 0.816,  0.816])

# %% [markdown]
# 用 `var` 方法计算方差：

# %%
a.var(axis=1)
# Out:
# array([ 0.667,  0.667])

# %% [markdown]
# 或者使用函数：

# %%
var(a, axis=1)
# Out:
# array([ 0.667,  0.667])

# %%
std(a, axis=1)
# Out:
# array([ 0.816,  0.816])

# %% [markdown]
# ## 5.7 clip 方法

# %% [markdown]
# 将数值限制在某个范围：

# %%
a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
a.clip(3,5)
# Out:
# array([[3, 3, 3],
#        [4, 5, 5]])

# %% [markdown]
# 小于3的变成3，大于5的变成5。

# %% [markdown]
# ## 5.8 ptp 方法

# %% [markdown]
# 计算最大值和最小值之差：

# %%
a.ptp(axis=1)
# Out:
# array([2, 2])

# %%
a.ptp()
# Out:
# 5

# %% [markdown]
# ## 5.9 round 方法

# %% [markdown]
# 近似，默认到整数：

# %%
a = array([1.35, 2.5, 1.6])

# %% [markdown]
# 这里，.5的近似规则为近似到偶数值，可以参考：
#
# https://en.wikipedia.org/wiki/Rounding#Round_half_to_odd

# %%
a.round()
# Out:
# array([ 1.,  2.,  2.])

# %% [markdown]
# 近似到一位小数：

# %%
a.round(decimals=1)
# Out:
# array([ 1.4,  2.5,  1.5])
