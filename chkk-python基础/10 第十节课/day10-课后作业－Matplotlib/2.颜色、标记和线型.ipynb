# %% [markdown]
# # 颜色、标记和线型

# %% [markdown]
# matplotlib的plot函数不仅可以指定linestyle和color,还可以加上一些标记（marker）,以强调具体的数据点。
# 格式字符串中，标记类型和线型必须放在颜色后面：

# %%
import matplotlib.pyplot as plt
from numpy.random import randn
