# %% [markdown]
# # 设置标题、轴标签、刻度以及刻度标签

# %% [markdown]
# Tips:仅对Axesubplot起作用。
#
# plt.subplots() 返回一个 Figure实例fig 和一个 AxesSubplot实例ax
#
# https://blog.csdn.net/u012762410/article/details/78968708

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from numpy.random import randn

# %% [markdown]
# - set_xticks:指定数据范围中刻度的位置

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(randn(1000).cumsum())
ticks = ax.set_xticks([0, 250, 500, 750, 1000])

# %% [markdown]
# - set_xticklabels:将任何其他的值用作标签，取代刻度值

# %% [markdown]
# - set_xlabel:为x轴设置一个名称

# %%
# Out:
# Text(0.5,0,'Stages')

# %% [markdown]
# - set_title:为图设置一个标题

# %%
# Out:
# Text(0.5,1,'My first Matplotlib plot')
