# %% [markdown]
# # 添加图例

# %% [markdown]
# 图例（legend）:用于标识图表元素的重要工具。

# %% [markdown]
# ### 添加subplot的时候传入label参数

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from numpy.random import randn

# %% [markdown]
# 可以调用ax.legend()或者plt.legend()来自动创建图例，参数loc指定图例的位置。
