# %% [markdown]
# # Figure和Subplot

# %% [markdown]
# Figure上有3张子图,plt.plot(randn(50).cumsum(), 'k--')，默认在最后一张上绘制，如果没有创建figure，则创建一个figure再绘制：

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Tips:Figure 对象会在每个cell的最后被清除，故需要在每个cell中为plot声明figure对象。

# %% [markdown]
# 更为简便直接的方法——plt.subplots,它可以创建一个新的Figure,并返回一个含有已创建的subplot对象的Numpy数组：

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F43E48E080>,
# ...
#       dtype=object)

# %% [markdown]
# 通过指定sharex和sharey使所有subplot应该使用相同的X轴或Y轴

# %% [markdown]
# 调整subplot周围的间距：subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=None),其中wspace和hspace控制subplot间的距离。
