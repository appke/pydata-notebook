# %% [markdown]
# ## 披萨店顾客数据

# %%
import seaborn as sns

# %%
tips=sns.load_dataset('tips')

# %% [markdown]
# ## 1.带状图
#
# 离散数据 和 连续数据 之间的关系

# %%
sns.stripplot(data=tips, x='day', y='total_bill', jitter=False)

# %%
sns.stripplot(data=tips, x='day', y='total_bill', jitter=True) #jitter 抖动

# %% [markdown]
# ## 2.蜂群图
#
# ### 离散数据 和 连续数据 之间的关系-密度排列
#
# 带状图的补充
#
# 不允许在一起

# %%
sns.swarmplot(data=tips, x='day', y='total_bill')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## 3.Hue-分组参数
#
# 分析每天中，午餐和晚餐的账单分布

# %%
sns.swarmplot(data=tips, x='day', y='total_bill', hue='time')

# %% [markdown]
# 每天的付账人群中的性别分布

# %%
sns.swarmplot(data=tips, x='day', y='total_bill', hue='sex')

# %%
sns.swarmplot(data=tips, x='day', y='total_bill', hue='size')

# %% [markdown]
# ### 供应链预测：
#
# 账单，备货，采购链
#
# 硬件采购，提前2个月预测
#
# 对市场预测，备货，供应链
#
# 稍微delay供应商不高兴，囤货，年报不好看
#
# 逻辑回归、SVM、神经网络

# %%
sns.swarmplot(data=tips, x='size', y='total_bill')

# %% [markdown]
# pizza的不同size的基础价格

# %%
tips['size'].corr(tips['total_bill'])
# Out:
# 0.59831513090490129

# %% [markdown]
# ## 4.箱线图
#
# 外部利群点，不和分布规律
#
# 中位数、1/4位点、3/4位点

# %%
sns.boxplot('day', 'total_bill',data=tips)

# %%
sns.swarmplot('day', 'total_bill',data=tips)

# %%
sns.boxplot('day', 'total_bill',data=tips, hue='time')

# %% [markdown]
# ## 提琴图
#
# 对称
#
# 如何表示total_bill 的概率分布
#
# 概率密度

# %%
sns.violinplot('day', 'total_bill', data=tips, hue='time')

# %%
sns.violinplot('day', 'total_bill', data=tips, hue='time', split=True)

# %% [markdown]
# ## 多图展示
#
# 花朵里的种子

# %%
sns.violinplot('day', 'total_bill', data=tips)
sns.swarmplot('day', 'total_bill', data=tips, color='white')
